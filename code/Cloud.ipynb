# %%
import os
import numpy as np
import gym
from gym.spaces import Box, MultiDiscrete, Dict
from stable_baselines3 import PPO, A2C

# %%
n = 300 # Number of VMs
m = 30 # Number of Servers

# %%
class CpuMem():
    def __init__(self, cpu, mem):
        self.cpu = cpu
        self.mem = mem
    def get_arr(self):
        return [self.cpu, self.mem]
    def __le__(self, other):
        return self.cpu <= other.cpu and self.mem <= other.mem
    def __isub__(self, other):
        self.cpu -= other.cpu
        self.mem -= other.mem
        return self

STOP = 2048

class CloudEnv(gym.Env):
    def __init__(self):
        self.reset()
        self.action_space = MultiDiscrete([n, m])
        self.observation_space = Box(low=0, high=STOP, shape=(n + m, 2), dtype=np.float32)

    def get_state(self):
        ans = np.zeros([n + m, 2])
        for i in range(n):
            ans[i] = self.vms[i].get_arr()
        for i in range(m):
            ans[n + i] = self.servers[i].get_arr()
        return ans

    def get_reward(self):
        ans = 0
        for vm in self.vms:
            if vm.cpu == STOP:
                ans += 1
        reward = ans - self.was
        self.was = ans
        return 2 * reward - 1
    
    def can_move(self, vm_index, server_index):
        vm = self.vms[vm_index]
        server = self.servers[server_index]
        if vm.cpu == STOP:
            return False
        if not vm <= server:
            return False
        return True

    def is_done(self):
        for vm in self.vms:
            if vm.cpu == STOP:
                continue
            for server in self.servers:
                if vm <= server:
                    return False
        return True

    def render(self):
        pass

    def step(self, action):
        vm_index, server_index = action[0], action[1]
        if self.can_move(vm_index, server_index):
            self.servers[server_index] -= self.vms[vm_index]
            self.vms[vm_index] = CpuMem(STOP, STOP)
        return self.get_state(), self.get_reward(), self.is_done(), {}

    def reset(self):
        self.vms = []
        self.servers = []
        for i in range(n):
            self.vms.append(CpuMem(1, 2))
        for i in range(m):
            self.servers.append(CpuMem(16, 32))
        self.was = 0
        return self.get_state()

# %%
env = CloudEnv()

# %%
# from stable_baselines3.common.vec_env import VecFrameStack
# env = VecFrameStack(env, n_stack=8)

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO(policy='MlpPolicy', env=env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training/Logs/PPO_19
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.93e+03  |
# |    ep_rew_mean     | -1.33e+03 |
# | time/              |           |
# |    fps             | 543       |
# |    iterations      | 1         |
# |    time_elapsed    | 3         |
# |    total_timesteps | 2048      |
# ----------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.93e+03   |
# |    ep_rew_mean          | -1.33e+03  |
# | time/                   |            |
# |    fps                  | 417        |
# |    iterations           | 2          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.03391386 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -9.08      |
# |    explained_variance   | -0.0731    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.39       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0723    |
# |    value_loss           | 65         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | -1.52e+03   |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 3           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.022205185 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.97       |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.055      |
# |    value_loss           | 82.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21e+03    |
# |    ep_rew_mean          | -1.61e+03   |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 4           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.020857602 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.93       |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0497     |
# |    value_loss           | 73.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.15e+03    |
# |    ep_rew_mean          | -1.55e+03   |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 5           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.022747703 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.97       |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0488     |
# |    value_loss           | 61.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.12e+03    |
# |    ep_rew_mean          | -1.52e+03   |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 6           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.022551134 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.95       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0486     |
# |    value_loss           | 48.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.18e+03    |
# |    ep_rew_mean          | -1.58e+03   |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 7           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023642458 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.96       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.53        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 43.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | -1.58e+03  |
# | time/                   |            |
# |    fps                  | 373        |
# |    iterations           | 8          |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02918282 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.96      |
# |    explained_variance   | 0.362      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.46       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.053     |
# |    value_loss           | 37.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.37e+03    |
# |    ep_rew_mean          | -1.77e+03   |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 9           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.024037316 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.9        |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0326     |
# |    value_loss           | 26.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.39e+03    |
# |    ep_rew_mean          | -1.79e+03   |
# | time/                   |             |
# |    fps                  | 375         |
# |    iterations           | 10          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.058091745 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.89       |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.32        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0543     |
# |    value_loss           | 31.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.39e+03   |
# |    ep_rew_mean          | -1.79e+03  |
# | time/                   |            |
# |    fps                  | 376        |
# |    iterations           | 11         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.03125317 |
# |    clip_fraction        | 0.32       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.73      |
# |    explained_variance   | 0.487      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.49       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0427    |
# |    value_loss           | 29.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.52e+03   |
# |    ep_rew_mean          | -1.92e+03  |
# | time/                   |            |
# |    fps                  | 381        |
# |    iterations           | 12         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.03698106 |
# |    clip_fraction        | 0.257      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.69      |
# |    explained_variance   | 0.0249     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.28       |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.022     |
# |    value_loss           | 8.23       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.52e+03    |
# |    ep_rew_mean          | -1.92e+03   |
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 13          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021474103 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.83       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 66          |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0284     |
# |    value_loss           | 33          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.73e+03   |
# |    ep_rew_mean          | -2.13e+03  |
# | time/                   |            |
# |    fps                  | 385        |
# |    iterations           | 14         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.04253324 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.76      |
# |    explained_variance   | 0.00717    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0123    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0232    |
# |    value_loss           | 3.29       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.73e+03    |
# |    ep_rew_mean          | -2.13e+03   |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 15          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.017695721 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.8        |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 35.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.84e+03   |
# |    ep_rew_mean          | -2.24e+03  |
# | time/                   |            |
# |    fps                  | 374        |
# |    iterations           | 16         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.03987065 |
# |    clip_fraction        | 0.316      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.74      |
# |    explained_variance   | 0.0294     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0506     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0297    |
# |    value_loss           | 1.58       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.88e+03    |
# |    ep_rew_mean          | -2.28e+03   |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 17          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010506222 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.75       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.14        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.018      |
# |    value_loss           | 42.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.88e+03    |
# |    ep_rew_mean          | -2.28e+03   |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 18          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016192524 |
# |    clip_fraction        | 0.0916      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.7        |
# |    explained_variance   | 0.428       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.78        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 41.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.88e+03    |
# |    ep_rew_mean          | -2.28e+03   |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 19          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.019823724 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.7        |
# |    explained_variance   | 0.741       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.84        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0367     |
# |    value_loss           | 5.85        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.06e+03    |
# |    ep_rew_mean          | -2.46e+03   |
# | time/                   |             |
# |    fps                  | 366         |
# |    iterations           | 20          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.033102885 |
# |    clip_fraction        | 0.387       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.66       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.116       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0301     |
# |    value_loss           | 0.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.06e+03    |
# |    ep_rew_mean          | -2.46e+03   |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 21          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016774505 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.7        |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.85        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 40.9        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 3.06e+03  |
# |    ep_rew_mean          | -2.46e+03 |
# | time/                   |           |
# |    fps                  | 373       |
# |    iterations           | 22        |
# |    time_elapsed         | 120       |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0269412 |
# |    clip_fraction        | 0.353     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.69     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.138     |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -0.0313   |
# |    value_loss           | 0.603     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.06e+03    |
# |    ep_rew_mean          | -2.46e+03   |
# | time/                   |             |
# |    fps                  | 373         |
# |    iterations           | 23          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025912762 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.69       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.055       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0297     |
# |    value_loss           | 0.327       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+03     |
# |    ep_rew_mean          | -2.9e+03    |
# | time/                   |             |
# |    fps                  | 371         |
# |    iterations           | 24          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.027552476 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.6        |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0291     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 0.144       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+03     |
# |    ep_rew_mean          | -2.9e+03    |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 25          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010450272 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.57       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.672       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 41.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.5e+03    |
# |    ep_rew_mean          | -2.9e+03   |
# | time/                   |            |
# |    fps                  | 369        |
# |    iterations           | 26         |
# |    time_elapsed         | 144        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01987281 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.61      |
# |    explained_variance   | 0.726      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.91       |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0324    |
# |    value_loss           | 3.85       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+03     |
# |    ep_rew_mean          | -2.9e+03    |
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 27          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.025191586 |
# |    clip_fraction        | 0.333       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.5        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.169       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0353     |
# |    value_loss           | 0.252       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.5e+03    |
# |    ep_rew_mean          | -2.9e+03   |
# | time/                   |            |
# |    fps                  | 370        |
# |    iterations           | 28         |
# |    time_elapsed         | 154        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.02569595 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.42      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0174    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0254    |
# |    value_loss           | 0.0602     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.5e+03     |
# |    ep_rew_mean          | -2.9e+03    |
# | time/                   |             |
# |    fps                  | 368         |
# |    iterations           | 29          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.025975993 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.38       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00103     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 0.0744      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.01e+03    |
# |    ep_rew_mean          | -3.41e+03   |
# | time/                   |             |
# |    fps                  | 367         |
# |    iterations           | 30          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.021370709 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.34       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0337     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 0.0368      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.01e+03    |
# |    ep_rew_mean          | -3.41e+03   |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 31          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014176988 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.45       |
# |    explained_variance   | 0.282       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.74        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 53.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.01e+03    |
# |    ep_rew_mean          | -3.41e+03   |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 32          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.025680922 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.39       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.224       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0332     |
# |    value_loss           | 0.496       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 4.01e+03  |
# |    ep_rew_mean          | -3.41e+03 |
# | time/                   |           |
# |    fps                  | 364       |
# |    iterations           | 33        |
# |    time_elapsed         | 185       |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.0239592 |
# |    clip_fraction        | 0.312     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -8.31     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.019     |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.0269   |
# |    value_loss           | 0.123     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.01e+03    |
# |    ep_rew_mean          | -3.41e+03   |
# | time/                   |             |
# |    fps                  | 365         |
# |    iterations           | 34          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.024988132 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.23       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0278     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 0.0493      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.01e+03    |
# |    ep_rew_mean          | -3.41e+03   |
# | time/                   |             |
# |    fps                  | 364         |
# |    iterations           | 35          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.025817797 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.19       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0151     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 0.106       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.49e+03    |
# |    ep_rew_mean          | -3.89e+03   |
# | time/                   |             |
# |    fps                  | 362         |
# |    iterations           | 36          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.023782684 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.21       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0422     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 0.0112      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 4.49e+03     |
# |    ep_rew_mean          | -3.89e+03    |
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 37           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0124724405 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.37        |
# |    explained_variance   | 0.325        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.95         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0176      |
# |    value_loss           | 43.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.49e+03    |
# |    ep_rew_mean          | -3.89e+03   |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 38          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.022270452 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.32       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0809      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0307     |
# |    value_loss           | 0.406       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.49e+03   |
# |    ep_rew_mean          | -3.89e+03  |
# | time/                   |            |
# |    fps                  | 359        |
# |    iterations           | 39         |
# |    time_elapsed         | 222        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.02384654 |
# |    clip_fraction        | 0.325      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.27      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.000593  |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.031     |
# |    value_loss           | 0.155      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.49e+03   |
# |    ep_rew_mean          | -3.89e+03  |
# | time/                   |            |
# |    fps                  | 359        |
# |    iterations           | 40         |
# |    time_elapsed         | 227        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02374043 |
# |    clip_fraction        | 0.327      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -8.16      |
# |    explained_variance   | 2.38e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0319    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.026     |
# |    value_loss           | 0.0442     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.49e+03    |
# |    ep_rew_mean          | -3.89e+03   |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 41          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.026503969 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.09       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000561    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0257     |
# |    value_loss           | 0.0566      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.96e+03    |
# |    ep_rew_mean          | -4.36e+03   |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 42          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.022920193 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.01       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 0.00715     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.96e+03    |
# |    ep_rew_mean          | -4.36e+03   |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 43          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008296609 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.1        |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.5        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 47.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.96e+03    |
# |    ep_rew_mean          | -4.36e+03   |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 44          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.023608832 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.1        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.209       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0338     |
# |    value_loss           | 0.489       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.09e+03    |
# |    ep_rew_mean          | -4.49e+03   |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 45          |
# |    time_elapsed         | 255         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.024289086 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.14       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0429      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0323     |
# |    value_loss           | 0.221       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.09e+03     |
# |    ep_rew_mean          | -4.49e+03    |
# | time/                   |              |
# |    fps                  | 360          |
# |    iterations           | 46           |
# |    time_elapsed         | 261          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0072438344 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -8.19        |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.06         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0142      |
# |    value_loss           | 45.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.09e+03    |
# |    ep_rew_mean          | -4.49e+03   |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 47          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.019425886 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.3        |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.25        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 2.74        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.09e+03    |
# |    ep_rew_mean          | -4.49e+03   |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 48          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.022971578 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.22       |
# |    explained_variance   | 0.567       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.811       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0283     |
# |    value_loss           | 2.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.09e+03    |
# |    ep_rew_mean          | -4.49e+03   |
# | time/                   |             |
# |    fps                  | 360         |
# |    iterations           | 49          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.027307447 |
# |    clip_fraction        | 0.322       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -8.15       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.027       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 0.105       |
# -----------------------------------------

# %%
state = env.reset()

done = False
score = 0
steps = 0
while not done:
    steps += 1
    action = env.action_space.sample()
    state, reward, done, additional_info = env.step(action)
#     print(action)
#     print(done)
#     print(reward)
#     print(state)
    score += reward
print(steps)
print(score)
# Out:
# 1695
# -1695

# %%
gym.Env??
