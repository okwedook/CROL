# %%
import os
import gym
import numpy as np
from gym.spaces import Box, Discrete
from stable_baselines3 import PPO

# %%
avg_temp = 38
variance = 4
good_variance = 1
low_good = avg_temp - good_variance
high_good = avg_temp + good_variance

# state, reward, done, additional_info = env.step(action)

class CloudEnv(gym.Env):
    def __init__(self):
        self.reset()
        self.action_space = Discrete(2)
        self.observation_space = Box(low=0, high=100, shape=(1,), dtype=np.float32)

    def get_state(self):
        return self.temp

    def get_reward(self):
        if low_good <= self.temp and self.temp >= high_good:
            return 1
#         return -max(low_good - self.temp, self.temp - high_good)
        return -1

    def is_done(self):
        return self.timestamp >= 100

    def render(self):
        pass

    def step(self, action):
        if action == 0:
            self.temp += 1
        else:
            self.temp -= 1
        self.temp = max(0, min(100, self.temp))
        self.timestamp += 1
        return self.get_state(), self.get_reward(), self.is_done(), {}

    def reset(self):
        self.temp = np.random.randint(avg_temp - variance, avg_temp + variance)
        self.timestamp = 0
        return self.get_state()

# %%
env = CloudEnv()

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO(policy='MlpPolicy', env=env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training/Logs/PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 4.6      |
# | time/              |          |
# |    fps             | 1667     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 33          |
# | time/                   |             |
# |    fps                  | 1138        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020043207 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.674      |
# |    explained_variance   | 0.00216     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.8        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 142         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 46.9       |
# | time/                   |            |
# |    fps                  | 1005       |
# |    iterations           | 3          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01420407 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.632     |
# |    explained_variance   | 0.129      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 46         |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0156    |
# |    value_loss           | 96         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 58.4        |
# | time/                   |             |
# |    fps                  | 967         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010067507 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.581      |
# |    explained_variance   | -0.000742   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 72.1        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 65.5          |
# | time/                   |               |
# |    fps                  | 946           |
# |    iterations           | 5             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00047935516 |
# |    clip_fraction        | 0.0237        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.55         |
# |    explained_variance   | -0.0427       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 37            |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -3.9e-05      |
# |    value_loss           | 78.1          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 85.8        |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.002753436 |
# |    clip_fraction        | 0.0199      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | -0.000325   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.000201    |
# |    value_loss           | 94.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 91.8         |
# | time/                   |              |
# |    fps                  | 886          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0024187244 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.495       |
# |    explained_variance   | -8.76e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.7         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | 3.92e-05     |
# |    value_loss           | 110          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 95.2         |
# | time/                   |              |
# |    fps                  | 877          |
# |    iterations           | 8            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0009969178 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.453       |
# |    explained_variance   | -3.83e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.3         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000745    |
# |    value_loss           | 128          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 96           |
# | time/                   |              |
# |    fps                  | 869          |
# |    iterations           | 9            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0005116341 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.41        |
# |    explained_variance   | -2.11e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 83.6         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00089     |
# |    value_loss           | 135          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 96.2         |
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 10           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0003010322 |
# |    clip_fraction        | 0.00845      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.424       |
# |    explained_variance   | -1.53e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.4         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.000379     |
# |    value_loss           | 150          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 96.6         |
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 11           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0032175537 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.382       |
# |    explained_variance   | -1.03e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 128          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000561    |
# |    value_loss           | 151          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 96.9         |
# | time/                   |              |
# |    fps                  | 833          |
# |    iterations           | 12           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0011582066 |
# |    clip_fraction        | 0.0261       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.329       |
# |    explained_variance   | -7.75e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85.9         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000622    |
# |    value_loss           | 161          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.3         |
# | time/                   |              |
# |    fps                  | 829          |
# |    iterations           | 13           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0036791633 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.345       |
# |    explained_variance   | -5.48e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.6         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000535    |
# |    value_loss           | 159          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.4        |
# | time/                   |             |
# |    fps                  | 827         |
# |    iterations           | 14          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.002118663 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.335      |
# |    explained_variance   | -4.77e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.1        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -3.54e-06   |
# |    value_loss           | 168         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.4         |
# | time/                   |              |
# |    fps                  | 819          |
# |    iterations           | 15           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0015615139 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | -3.7e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 105          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000721    |
# |    value_loss           | 163          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.6         |
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 16           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0027970786 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.368       |
# |    explained_variance   | -3.22e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75           |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000448    |
# |    value_loss           | 169          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.3         |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 17           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0016525879 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.369       |
# |    explained_variance   | -2.5e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.6         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 165          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.1         |
# | time/                   |              |
# |    fps                  | 818          |
# |    iterations           | 18           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0012547664 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.301       |
# |    explained_variance   | -2.15e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.3         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 172          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97          |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 19          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004467123 |
# |    clip_fraction        | 0.049       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.343      |
# |    explained_variance   | -1.79e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 60.5        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 165         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.2         |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 20           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0009601646 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.348       |
# |    explained_variance   | -1.43e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.7         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.0013       |
# |    value_loss           | 172          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 97.4          |
# | time/                   |               |
# |    fps                  | 813           |
# |    iterations           | 21            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00073907373 |
# |    clip_fraction        | 0.0243        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.367        |
# |    explained_variance   | -1.43e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 86.9          |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 0.000884      |
# |    value_loss           | 166           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.7         |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 22           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0023376541 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.347       |
# |    explained_variance   | -1.07e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.6         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.00024      |
# |    value_loss           | 173          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.2         |
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 23           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0023656841 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.349       |
# |    explained_variance   | -9.54e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.3         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 0.000961     |
# |    value_loss           | 166          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.1         |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 24           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0010145761 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.285       |
# |    explained_variance   | -8.34e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58           |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.000828     |
# |    value_loss           | 172          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 96.9          |
# | time/                   |               |
# |    fps                  | 817           |
# |    iterations           | 25            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00031630558 |
# |    clip_fraction        | 0.022         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.256        |
# |    explained_variance   | -7.15e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 60.1          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | 0.00122       |
# |    value_loss           | 166           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 96.9        |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 26          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.018291663 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.288      |
# |    explained_variance   | -8.34e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.4        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00131     |
# |    value_loss           | 172         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 96.8        |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 27          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004546658 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.343      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.5        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0019      |
# |    value_loss           | 166         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.1         |
# | time/                   |              |
# |    fps                  | 819          |
# |    iterations           | 28           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0067515746 |
# |    clip_fraction        | 0.0612       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.366       |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.3         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000331    |
# |    value_loss           | 167          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 97.1       |
# | time/                   |            |
# |    fps                  | 820        |
# |    iterations           | 29         |
# |    time_elapsed         | 72         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.01379568 |
# |    clip_fraction        | 0.0565     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.371     |
# |    explained_variance   | -4.77e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 75.8       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.00124    |
# |    value_loss           | 171        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.6         |
# | time/                   |              |
# |    fps                  | 820          |
# |    iterations           | 30           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0022093127 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.348       |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.5         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.00181      |
# |    value_loss           | 168          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.4         |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 31           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0022978762 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.338       |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.8         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000293    |
# |    value_loss           | 174          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.4         |
# | time/                   |              |
# |    fps                  | 821          |
# |    iterations           | 32           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0026520677 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.368       |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67.8         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.00227      |
# |    value_loss           | 168          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.7        |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 33          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009054995 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.407      |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.1        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00308    |
# |    value_loss           | 174         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 97.9       |
# | time/                   |            |
# |    fps                  | 821        |
# |    iterations           | 34         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.00877001 |
# |    clip_fraction        | 0.0564     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.387     |
# |    explained_variance   | -4.77e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 69.9       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | 0.00116    |
# |    value_loss           | 168        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.8         |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 35           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0038151017 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.358       |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 79.2         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.00269      |
# |    value_loss           | 175          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.7         |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 36           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0061440975 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.364       |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 113          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00196      |
# |    value_loss           | 168          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.9        |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 37          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.010078184 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.338      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00406     |
# |    value_loss           | 175         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.6         |
# | time/                   |              |
# |    fps                  | 824          |
# |    iterations           | 38           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0031214275 |
# |    clip_fraction        | 0.0686       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.287       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.3         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.00306      |
# |    value_loss           | 168          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.9        |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 39          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.005193242 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.303      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.2        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00464     |
# |    value_loss           | 174         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.6        |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 40          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012097951 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.29       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.3        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00414     |
# |    value_loss           | 167         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.7         |
# | time/                   |              |
# |    fps                  | 825          |
# |    iterations           | 41           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0022350647 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.277       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.3         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.00346      |
# |    value_loss           | 173          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.6        |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 42          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011909631 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.355      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.6        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 167         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.8        |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 43          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009567106 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.364      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.4        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00328     |
# |    value_loss           | 173         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.3        |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 44          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009237232 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.361      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 117         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00212     |
# |    value_loss           | 167         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.8         |
# | time/                   |              |
# |    fps                  | 825          |
# |    iterations           | 45           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0044351057 |
# |    clip_fraction        | 0.0998       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.7         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.00209      |
# |    value_loss           | 174          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.8        |
# | time/                   |             |
# |    fps                  | 825         |
# |    iterations           | 46          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014490152 |
# |    clip_fraction        | 0.0857      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.348      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 102         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00253     |
# |    value_loss           | 167         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 97.9        |
# | time/                   |             |
# |    fps                  | 826         |
# |    iterations           | 47          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.009636271 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.386      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97.2        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00245     |
# |    value_loss           | 173         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.8         |
# | time/                   |              |
# |    fps                  | 825          |
# |    iterations           | 48           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0047495267 |
# |    clip_fraction        | 0.0835       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.384       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 95.7         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00119      |
# |    value_loss           | 167          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 97.9         |
# | time/                   |              |
# |    fps                  | 823          |
# |    iterations           | 49           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0049122814 |
# |    clip_fraction        | 0.0918       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 81.1         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.00211      |
# |    value_loss           | 174          |
# ------------------------------------------

# %%
save_path = os.path.join('Training', 'Saved Models', 'ShowerTrainPPO100k')
model.save(save_path)
